# %%
import matplotlib.pyplot as plt

# %%
x=[1,1.5,2,2.5,3,3.5,3.6]
y=[7.5,8,8.5,9,9.5,10,10.5]

x1=[8,8.5,9,9.5,10,10.5,11]
y1=[3,3.5,3.7,4,4.5,5,5.2]

plt.scatter(x,y, label='high incomes low saving', color='r')
plt.scatter(x1,y1, label='low income high saving', color='g')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Python Matplotlib : Pie Chart

import matplotlib.pyplot as plt
slices = [7,2,2,13]
activities =['sleeping','eating','working','playing']
cols = ['c','m','r','b']

plt.pie(slices,
labels=activities,
colors=cols,
startangle=90,
shadow= True,
explode=(0,0,0.1,0),
autopct='%1.2f%%')   # .2f is the percentage formate--- how many points should be there after decimal point.
plt.title('Pie Plot')
plt.show()

# %%
#Python Matplotlib : Area Plot

import matplotlib.pyplot as plt
days = [1,2,3,4,5]
sleeping =[7,8,6,11,7]
eating = [2,3,4,3,2]
working =[7,8,7,2,2]
playing = [8,5,7,8,13]

plt.stackplot(days, sleeping,eating,working,playing,colors=['m','c','r','k'],labels=['sleeping','eating','working','playing'])

plt.xlabel('No. of Days')
plt.ylabel('Hours')
plt.title('Stack Plot')
plt.legend()
plt.show()
